# %% [markdown]
# ## Status of MFU Student

# %% [markdown]
# ## Data Cleaning & Feature Engineering

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('tcas1.csv')
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (23,24,26,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#    AcademicYear  AcademicSemester PrefixName     Sex  FacultyID  \
# 0          2562                 1       MISS  Female         10
# 1          2562                 1        MR.    Male         10
# 2          2562                 1        MR.    Male         10
# 3          2562                 1       MISS  Female         10
# 4          2562                 1       MISS  Female         10
#
#               FacultyName  DepartmentCode  \
# 0  School of Liberal Arts            1005
# 1  School of Liberal Arts            1005
# 2  School of Liberal Arts            1005
# 3  School of Liberal Arts            1005
# 4  School of Liberal Arts            1005
#
#                              DepartmentName MajorName  EntryTypeID  ... Q34  \
# 0  Thai Language and Culture for Foreigners       NaN           40  ... NaN
# 1  Thai Language and Culture for Foreigners       NaN           40  ... NaN
# 2  Thai Language and Culture for Foreigners       NaN           40  ... NaN
# ...

# %%
df.shape
# Out:
# (36401, 79)

# %%
df.dtypes
# Out:
# AcademicYear          int64
# AcademicSemester      int64
# PrefixName           object
# Sex                  object
# FacultyID             int64
#                      ...
# Q39                 float64
# Q40                 float64
# Q41                 float64
# Q42                 float64
# Status               object
# Length: 79, dtype: object

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 36396    False
# 36397    False
# 36398    False
# 36399    False
# 36400    False
# Length: 36401, dtype: bool

# %%
cat_data = df.select_dtypes(include=['object'])

# %%
cat_data = cat_data.drop(columns=['PrefixName'])
cat_data = cat_data.drop(columns=['LevelNameEng'])
cat_data = cat_data.drop(columns=['LevelName'])
cat_data = cat_data.drop(columns=['SchoolRegionName'])
cat_data = cat_data.drop(columns=['SchoolRegion'])
cat_data = cat_data.drop(columns=['SchoolProvince'])
cat_data = cat_data.drop(columns=['NationName'])
cat_data = cat_data.drop(columns=['EntryGroupName'])
cat_data = cat_data.drop(columns=['SchoolRegionNameEng'])
cat_data = cat_data.drop(columns=['SchoolName'])
cat_data = cat_data.drop(columns=['ApplicationDate'])
cat_data = cat_data.drop(columns=['StudentType'])
cat_data = cat_data.drop(columns=['ReligionName'])

# %%
cat_data.head(5)
# Out:
#       Sex             FacultyName                            DepartmentName  \
# 0  Female  School of Liberal Arts  Thai Language and Culture for Foreigners
# 1    Male  School of Liberal Arts  Thai Language and Culture for Foreigners
# 2    Male  School of Liberal Arts  Thai Language and Culture for Foreigners
# 3  Female  School of Liberal Arts  Thai Language and Culture for Foreigners
# 4  Female  School of Liberal Arts  Thai Language and Culture for Foreigners
#
#   MajorName EntryTypeName     HomeRegion Country ProvinceNameEng       Status
# 0       NaN     FOREIGNER  International   China           CHINA  MFU student
# 1       NaN     FOREIGNER  International   Korea         INCHEON  MFU student
# 2       NaN     FOREIGNER  International   China           CHINA  MFU student
# 3       NaN     FOREIGNER  International   China       GUANGDONG  MFU student
# 4       NaN     FOREIGNER  International     NaN           JAPAN  MFU student

# %%
cat_data.loc[df.HomeRegion =='Bankok', 'HomeRegion'] = 'Central'

# %%
sns.countplot(cat_data.HomeRegion)

# %%
fig, ax = plt.subplots(13,1 , figsize=(50, 300))
for i, subplot in zip(cat_data.columns, ax.flatten()):
    sns.countplot(cat_data[i], ax=subplot)

# %%
df =df.drop(columns=['Q1'])
df =df.drop(columns=['Q2'])
df =df.drop(columns=['Q3'])
df =df.drop(columns=['Q4'])
df =df.drop(columns=['Q5'])
df =df.drop(columns=['Q6'])
df =df.drop(columns=['Q7'])
df =df.drop(columns=['Q8'])
df =df.drop(columns=['Q9'])
df =df.drop(columns=['Q10'])
df =df.drop(columns=['Q11'])
df =df.drop(columns=['Q12'])
df =df.drop(columns=['Q13'])
df =df.drop(columns=['Q14'])
df =df.drop(columns=['Q15'])
df =df.drop(columns=['Q16'])
df =df.drop(columns=['Q17'])
df =df.drop(columns=['Q18'])
df =df.drop(columns=['Q19'])
df =df.drop(columns=['Q20'])
df =df.drop(columns=['Q21'])
df =df.drop(columns=['Q22'])
df =df.drop(columns=['Q23'])
df =df.drop(columns=['Q24'])
df =df.drop(columns=['Q25'])
df =df.drop(columns=['Q26'])
df =df.drop(columns=['Q27'])
df =df.drop(columns=['Q28'])
df =df.drop(columns=['Q29'])
df =df.drop(columns=['Q30'])
df =df.drop(columns=['Q31'])
df =df.drop(columns=['Q32'])
df =df.drop(columns=['Q33'])
df =df.drop(columns=['Q34'])
df =df.drop(columns=['Q35'])
df =df.drop(columns=['Q36'])
df =df.drop(columns=['Q37'])
df =df.drop(columns=['Q38'])
df =df.drop(columns=['Q39'])
df =df.drop(columns=['Q40'])
df =df.drop(columns=['Q41'])
df =df.drop(columns=['Q42'])
df =df.drop(columns=['AcademicSemester'])
df =df.drop(columns=['LevelID'])

# %%
num_data = df.select_dtypes(include='number') # get all numberic features
num_data = num_data.fillna(num_data.mean()) # fill all missing numeric feature with mean 
num_data
# Out:
#        AcademicYear  FacultyID  DepartmentCode  EntryTypeID  EntryGroupID  \
# 0              2562         10            1005           40        623210
# 1              2562         10            1005           40        623210
# 2              2562         10            1005           40        623210
# 3              2562         10            1005           40        623210
# 4              2562         10            1005           40        623210
# ...             ...        ...             ...          ...           ...
# 36396          2563         12            1205           29        633601
# 36397          2563         14            1407           29        633601
# 36398          2563         12            1205           29        633601
# 36399          2563         12            1205           29        633601
# 36400          2563         14            1407           29        633601
#
#        TCAS  EntryGPA  StudentTH  GPAX   GPA_Eng  GPA_Math   GPA_Sci   GPA_Sco
# ...

# %%
num_data = df.select_dtypes(include='number') # get all numberic attribues
num_data
# Out:
#        AcademicYear  FacultyID  DepartmentCode  EntryTypeID  EntryGroupID  \
# 0              2562         10            1005           40        623210
# 1              2562         10            1005           40        623210
# 2              2562         10            1005           40        623210
# 3              2562         10            1005           40        623210
# 4              2562         10            1005           40        623210
# ...             ...        ...             ...          ...           ...
# 36396          2563         12            1205           29        633601
# 36397          2563         14            1407           29        633601
# 36398          2563         12            1205           29        633601
# 36399          2563         12            1205           29        633601
# 36400          2563         14            1407           29        633601
#
#        TCAS  EntryGPA  StudentTH  GPAX  GPA_Eng  GPA_Math  GPA_Sci  GPA_Sco
# ...

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001EF1F449AC0>,
# ...
#       dtype=object)

# %%
new_df = pd.concat([num_data,cat_data],axis=1)

# %%
len(new_df[new_df.duplicated()])
# Out:
# 14048

# %%
new_df.drop_duplicates(inplace=True)

# %%
new_df = pd.concat([num_data,cat_data],axis=1)

# %%
new_df.reset_index(drop=True, inplace=True)
new_df.head()
# Out:
#    AcademicYear  FacultyID  DepartmentCode  EntryTypeID  EntryGroupID  TCAS  \
# 0          2562         10            1005           40        623210     5
# 1          2562         10            1005           40        623210     5
# 2          2562         10            1005           40        623210     5
# 3          2562         10            1005           40        623210     5
# 4          2562         10            1005           40        623210     5
#
#    EntryGPA  StudentTH  GPAX  GPA_Eng  ...  GPA_Sco     Sex  \
# 0      0.23          0   0.0      NaN  ...      NaN  Female
# 1      3.50          0   0.0      NaN  ...      NaN    Male
# 2       NaN          0   0.0      NaN  ...      NaN    Male
# 3       NaN          0   0.0      NaN  ...      NaN  Female
# 4       NaN          0   0.0      NaN  ...      NaN  Female
#
#               FacultyName                            DepartmentName MajorName  \
# ...

# %%
# Select only 2 numeric features 

# Create box plots for all numeric features
fig, ax = plt.subplots(13,2, figsize=(50, 300))
for i, subplot in zip(num_data.columns, ax.flatten()):
    sns.boxplot(num_data[i], ax=subplot)

# %%
new_df[['Country']]= new_df.Country.fillna('Thailand')

# %%
# fill all missing categorical features with "mode" 
cat_data =new_df.select_dtypes(exclude='number') # get all nominal/ordinal attributes
for col_name in cat_data.columns: 
    cat_data[col_name] = cat_data[col_name].fillna(cat_data[col_name].mode()[0])

cat_data
# Out:
# <ipython-input-24-eb31c4a256a9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_data[col_name] = cat_data[col_name].fillna(cat_data[col_name].mode()[0])
#           Sex              FacultyName  \
# 0      Female   School of Liberal Arts
# 1        Male   School of Liberal Arts
# 2        Male   School of Liberal Arts
# 3      Female   School of Liberal Arts
# 4      Female   School of Liberal Arts
# ...       ...                      ...
# 36396  Female     School of Management
# 36397  Female  School of Agro-industry
# 36398  Female     School of Management
# 36399  Female     School of Management
# 36400  Female  School of Agro-industry
#
#                                  DepartmentName MajorName  \
# ...
